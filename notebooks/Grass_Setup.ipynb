# %% [markdown]
# ## Create Grass Database if not already in existance

# %%
#get parameters
import sys
sys.path.append('..')
from src.grass_functions import*
from src.process_inputs import*

# %%
#project_info
#for project
Project_Area = 'francis_pond'
projection = '2263' #set to None if you want to use the DEM's original projection

# %%
home = pl.Path(os.getcwd())

# %%
# define GRASS data settings (adapt to your needs)
location = Project_Area+'_'+projection
mapset = 'PERMANENT'

# %%
initialize_grass_db(location, mapset, projection)
#initialize_grass_db(Location, Mapset, GRASS_GIS_Projection)
# Out:
# Database Location Exists
# Database Mapset Exists
# None
# {'GISDBASE': 'C:\\Users\\Curtis.Smith\\Documents\\grassdata', 'LOCATION_NAME': 'francis_pond_2263', 'MAPSET': 'PERMANENT'}

# %% [markdown]
# ## List Existing Data in DB

# %%
#list all grass files
grass_maps = list_existing_grass(print_it=True)
# Out:
# Available vector maps:
# aoi@PERMANENT
# aoi_buffer@PERMANENT
# stream_020302010201@PERMANENT
# tmp_bsn@PERMANENT
# tmp_bsn_buffer@PERMANENT
# v_carve_020302010201@PERMANENT
#
# Available raster maps:
# MASK@PERMANENT
# accum_020302010201@PERMANENT
# dem_020302010201@PERMANENT
# dem_020302010201_b@PERMANENT
# drain_dir_020302010201@PERMANENT
# r_streams_020302010201@PERMANENT
# r_twi_020302010201@PERMANENT
# subbasins_020302010201@PERMANENT

# %% [markdown]
# ## GRASS GIS Version Installed

# %%
#version for reference
gs.parse_command('g.version')
# Out:
# {'GRASS 7.8.8 (2023)': None}

# %% [markdown]
# ## Install Grass Add Ons

# %%
#desired extensions
exts = ['r.basin', 'r.accumulate', 'r.stream.snap','r.stream.distance', 'r.stream.basins','r.hypso','r.stream.stats', 'r.stream.order', 'r.width.funct', 'r.traveltime','r.wateroutlet.lessmem','r.lfp']

# %%
existing_exts = list(gs.parse_command('g.extension', flags='a'))
print(existing_exts, 'already installed')
# Out:
# ['r.basin', 'r.accumulate', 'r.stream.snap', 'r.stream.distance', 'r.stream.basins', 'r.hypso', 'r.stream.stats', 'r.stream.order', 'r.width.funct', 'r.traveltime', 'r.wateroutlet.lessmem'] already installed

# %%
home = pl.Path(os.getcwd()).parent
for ext in exts:
    if ext not in existing_exts:
        gs.run_command('g.extension', extension= ext,  operation= 'add',url=f"{home/'grassdata'/ext}.zip")
        print(f'added {ext} to grass module')
# Out:
# ---------------------------------------------------------------------------
# CalledModuleError                         Traceback (most recent call last)
# Cell In[46], line 4
#       2 for ext in exts:
#       3     if ext not in existing_exts:
# ----> 4         gs.run_command('g.extension', extension= ext,  operation= 'add',url=f"{home/'grassdata'/ext}.zip")
#       5         print(f'added {ext} to grass module')
#
# File C:\Program Files\GRASS GIS 7.8\etc\python\grass\script\core.py:441, in run_command(*args, **kwargs)
#     439 else:
#     440     returncode = ps.wait()
# --> 441 return handle_errors(returncode, returncode, args, kwargs)
#
# File C:\Program Files\GRASS GIS 7.8\etc\python\grass\script\core.py:342, in handle_errors(returncode, result, args, kwargs)
#     340 args = make_command(*args, **kwargs)
#     341 code = ' '.join(args)
# --> 342 raise CalledModuleError(module=None, code=code,
#     343                         returncode=returncode)
#
# CalledModuleError: Module run None g.extension extension=r.lfp operation=add url=C:\git\dem_prep\grassdata\r.lfp.zip ended with error
# Process ended with non-zero return code 1. See errors in the (error) output.
